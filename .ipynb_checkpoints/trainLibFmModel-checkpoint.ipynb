# %%
import pandas  as pd

##怎么划分训练集和测试集
##训练集的要求 1 尽量包含完所有搜索词  先随便来试一下哦，不要管那么多
from sklearn.cross_validation import train_test_split

data = pd.read_table('E:/competionfile/oppo/new/oppo_round1_train_20180929/oppo_round1_train_20180929.txt',names=[0,1,2,3,4],header=None,encoding='utf8').astype(str)
data = data[ data[4] != '音乐' ]
##去掉搜索词为null的情况
data.drop(  data[ data[0].isnull() ].index , inplace =True )
querydict = {}
queryset = set( data[0].value_counts().index )
cc=1
for i in queryset:
    querydict[i]=cc
    cc+=1
data['queryid'] = data[0].map( lambda x : querydict[x] )
data['realname'] = data[2]+data[3]
wzset = set( data['realname'].value_counts().index )
wzdict={}
cc=1
for i in wzset:
    wzdict[i]=cc
    cc+=1
data['wzid'] = data['realname'].map( lambda x : wzdict[x] )
data
# ydata = data[4]
# xdata = data[ [ 0,1,2,3 ] ]
# X_train, X_test, y_train, y_test = train_test_split(xdata, ydata, test_size=0.3, random_state=0) # 为了看模型在没有见过数据集上的表现，随机拿出数据集中30%的部分做测试
##将其转化为userid itemid rate这种形式，先将搜索词和
# Out:
# d:\Users\tkhoon\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#               0                                                  1  \
# 0            小品  {"小品大全宋小宝": "0.009", "小品相亲": "0.012", "小品剧本": ...
# 1          1368  {"13688cc赛马会": "0.059", "13685367892": "0.124"...
# 2          1368  {"13688cc赛马会": "0.059", "13685367892": "0.124"...
# 3            银耳  {"银耳汤的功效": "0.012", "银耳为什么不能天天吃": "0.009", "银耳...
# 4          月经量少  {"月经量少喝红糖水好吗": "0.010", "月经量少该怎么调理": "0.016", ...
# 5        168.1.  {"168.1.1登陆页面": "0.013", "168.1.100": "0.007",...
# 6          有道翻译  {"有道翻译官在线翻译": "0.001", "有道翻译官下载安装": "0.002", "...
# 7            生日  {"生日快乐图片": "0.039", "生日快乐祝福语": "0.068", "生日快乐英...
# 8        168.1.  {"168.1.1登陆页面": "0.013", "168.1.100": "0.007",...
# ...

# %%
data = pd.read_table('E:/competionfile/oppo/new/oppo_round1_train_20180929/oppo_round1_train_20180929.txt',names=[0,1,2,3,4],header=None,encoding='utf8').astype(str)
data = data[ data[4] != '音乐' ]
data[data[4].isnull()].shape
# Out:
# d:\Users\tkhoon\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# (0, 5)

# %%
import pandas  as pd

##怎么划分训练集和测试集
##训练集的要求 1 尽量包含完所有搜索词  先随便来试一下哦，不要管那么多
from sklearn.cross_validation import train_test_split

data = pd.read_table('E:/competionfile/oppo/new/oppo_round1_train_20180929/oppo_round1_vali_20180929.txt',names=[0,1,2,3,4],header=None,encoding='utf8').astype(str)
data = data[ data[4] != '音乐' ]
##去掉搜索词为null的情况
data.drop(  data[ data[0].isnull() ].index , inplace =True )
querydict = {}
queryset = set( data[0].value_counts().index )
cc=1
for i in queryset:
    querydict[i]=cc
    cc+=1
data['queryid'] = data[0].map( lambda x : querydict[x] )
data['realname'] = data[2]+data[3]
wzset = set( data['realname'].value_counts().index )
wzdict={}
cc=1
for i in wzset:
    wzdict[i]=cc
    cc+=1
data['wzid'] = data['realname'].map( lambda x : wzdict[x] )
f = open('e:/useritemratetrainvalid.txt','w')
# for  i  in 
X_train = data[[4,'queryid','wzid']]
X_train['rate'] = X_train[4]
for row in X_train.itertuples():
#     print(row)
    ss = str(row.wzid) + ' ' + str(row.queryid)+' '+str(row.rate)+"\n"
    f.writelines(ss)
#     print>>f
f.close()
# ydata = data[4]
# xdata = data[ [ 0,1,2,3 ] ]
# X_train, X_test, y_train, y_test = train_test_split(xdata, ydata, test_size=0.3, random_state=0) # 为了看模型在没有见过数据集上的表现，随机拿出数据集中30%的部分做测试
##将其转化为userid itemid rate这种形式，先将搜索词和
# Out:
# d:\Users\tkhoon\Anaconda3\lib\site-packages\ipykernel_launcher.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
ydata = data[4]
xdata = data[ [ 'queryid','wzid' ] ]
X_train, X_test, y_train, y_test = train_test_split(xdata, ydata, test_size=0.3, random_state=0) # 为了看模型在没有见过数据集上的表现，随机拿出数据集中30%的部分做测试
#将其转化为userid itemid rate这种形式，先将搜索词和

# %%
f = open('e:/useritemratetrain.txt','w')
# for  i  in 
X_train = data[[4,'queryid','wzid']]
X_train['rate'] = y_train
for row in X_train.itertuples():
#     print(row)
    ss = str(row.queryid) + ' '+str(row.wzid)+' '+str(row.rate)+"\n"
    f.writelines(ss)
#     print>>f
f.close()
# Out:
# d:\Users\tkhoon\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
import pandas as pd 
##得到结果
pred = pd.read_table('E:/competionfile/oppo/libfm/libfm-1.40/libfm-1.40/result.txt',header=None)[0].map(lambda x : 1 if x >= 0.42 else 0)
da = pd.read_table('E:/useritemratetrainvalid.txt',header=None,delimiter =' ')[2]
##计算libfm计算出来的结果的f1值
from sklearn.metrics import f1_score
print( f1_score( da , pred ) )
##可以看到最后计算出来的分数只有令人发指的0.098分，非常之耻辱，暂时弃坑了
# Out:
# 0.30408222631629983

# %%
##计算下精确度和召回率
from sklearn.metrics import classification_report
print(classification_report(da, pred)  )
# Out:
#              precision    recall  f1-score   support
#
#           0       0.63      0.76      0.69     31415
#           1       0.38      0.25      0.30     18585
#
# avg / total       0.54      0.57      0.55     50000

# %%
pred[ pred == 1 ].shape
# Out:
# (2883,)

# %%
import pandas as pd 
##得到结果
pred = pd.read_table('E:/develop/libfm-1.40/libfm-1.40/result.txt')
da = pd.read_table('E:/useritemrate.txt')

# %%
##和libfm相关的文件放在E:\competionfile\oppo\libfm下
##http://www.libfm.org/libfm-1.42.manual.pdf libfm操作手册
