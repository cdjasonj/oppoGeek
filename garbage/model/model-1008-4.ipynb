# %%
import pandas as pd
train= pd.read_csv('E:/competionfile/oppo/data/train_data_10_8_1.csv')
test = pd.read_csv('E:/competionfile/oppo/data/test_data_10_8_1.csv')
co_list = [ 'prefix_count',
       'title_count', 'tag_count', 'prefix_tag_count', 'prefix_title_count',
       'title_tag_count', 'prefix_title_tag_count', 'prefix_pred_0',
       'prefix_pred_1', 'query_prediction_pred_0', 'query_prediction_pred_1',
       'title_pred_0', 'title_pred_1', 'label', 'title_ctr', 'prefix_ctr',
       'tag_ctr', 'prefix_tag_ctr', 'title_tag_ctr', 'prefix_title_ctr',
       'smi_pre_ti', 'prefix_len', 'title_len']
train_data = train[co_list]
test_data  = test[co_list]
train_data['prefix_title_tag_ctr_muti_prefix_len'] = train_data['prefix_title_ctr']*train_data['prefix_len']
test_data['prefix_title_tag_ctr_muti_prefix_len'] = test_data['prefix_title_ctr']*test_data['prefix_len']

train_data['prefix_title_tag_ctr_muti_title_len'] = train_data['prefix_title_ctr']*train_data['title_len']
test_data['prefix_title_tag_ctr_muti_title_len'] = test_data['prefix_title_ctr']*test_data['title_len']
# train.drop('Unnamed: 0',axis=1,inplace=True)
# test.drop('Unnamed: 0',axis=1,inplace=True)

# train_title_len = pd.read_csv('E:/competionfile/oppo/data/singleFeature/title_len.csv',header=None)
# test_title_len = pd.read_csv('E:/competionfile/oppo/data/singleFeature/test_title_len.csv',header=None)
# train['title_len'] = train_pre_titile_tag_ctr
# test['title_len'] = test_pre_titile_tag_ctr

train_X_data = train_data.drop(['label'],axis=1)
train_Y_data = train_data['label']
test_X_data = test_data.drop(['label'],axis=1)
vali_data = test_data['label']
pd.set_option('display.max_columns',55)
# Out:
# d:\Users\tkhoon\Anaconda3\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]
# d:\Users\tkhoon\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# d:\Users\tkhoon\Anaconda3\lib\site-packages\ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
train_X_data.drop('prefix_title_tag_ctr_muti_prefix_len',axis=1,inplace=True)
test_X_data.drop('prefix_title_tag_ctr_muti_prefix_len',axis=1,inplace=True)

train_X_data.drop('prefix_title_tag_ctr_muti_title_len',axis=1,inplace=True)
test_X_data.drop('prefix_title_tag_ctr_muti_title_len',axis=1,inplace=True)

# %%
# # test_data.shape
# train_X_data['prefix_title_ctr'] =prefix_title_ctr
# test_X_data['prefix_title_ctr'] =test_prefix_title_ctr


train_X_data = train_X_data.drop('prefix_title_tag_count',axis=1)
test_X_data =  test_X_data.drop('prefix_title_tag_count',axis=1)

# %%
train_X_data.columns
# Out:
# Index(['prefix_count', 'title_count', 'tag_count', 'prefix_tag_count',
#        'prefix_title_count', 'title_tag_count', 'prefix_title_tag_count',
#        'prefix_pred_0', 'prefix_pred_1', 'query_prediction_pred_0',
#        'query_prediction_pred_1', 'title_pred_0', 'title_pred_1', 'title_ctr',
#        'prefix_ctr', 'tag_ctr', 'prefix_tag_ctr', 'title_tag_ctr',
#        'prefix_title_ctr', 'smi_pre_ti', 'prefix_len', 'title_len',
#        'smooth_prefix_title_tag_ctr', 'pre_title_tag_ctr'],
#       dtype='object')

# %%
## 加入prefix_tittle_tag_ctr
train_pre_titile_tag_ctr = pd.read_csv('E:/competionfile/oppo/data/singleFeature/prefix_title_tag_ctr.csv',header=None)
test_pre_titile_tag_ctr = pd.read_csv('E:/competionfile/oppo/data/singleFeature/test_prefix_title_tag_ctr.csv',header=None)
train['pre_title_tag_ctr'] = train_pre_titile_tag_ctr
test['pre_title_tag_ctr'] = test_pre_titile_tag_ctr
train_data['pre_title_tag_ctr'] = train_pre_titile_tag_ctr
test_data['pre_title_tag_ctr'] = test_pre_titile_tag_ctr
train_X_data = train_data.drop(['label'],axis=1)
train_Y_data = train_data['label']
test_X_data = test_data.drop(['label'],axis=1)
vali_data = test_data['label']
# Out:
# Exception ignored in: <bound method DMatrix.__del__ of <xgboost.core.DMatrix object at 0x0000017903D0CF60>>
# Traceback (most recent call last):
#   File "d:\Users\tkhoon\Anaconda3\lib\site-packages\xgboost\core.py", line 366, in __del__
#     if self.handle is not None:
# AttributeError: 'DMatrix' object has no attribute 'handle'
# d:\Users\tkhoon\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# d:\Users\tkhoon\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
## 加入prefix_tittle_tag_ctr
# train_pre_titile_tag_ctr = pd.read_csv('E:/competionfile/oppo/data/singleFeature/smooth_pre_title_tag_ctr.csv',header=None)
# test_pre_titile_tag_ctr = pd.read_csv('E:/competionfile/oppo/data/singleFeature/test_smooth_pre_title_tag_ctr.csv',header=None)
train['smooth_prefix_title_tag_ctr'] = train_pre_titile_tag_ctr
test['smooth_prefix_title_tag_ctr'] = test_pre_titile_tag_ctr
train_data['smooth_prefix_title_tag_ctr'] = train_pre_titile_tag_ctr
test_data['smooth_prefix_title_tag_ctr'] = test_pre_titile_tag_ctr
train_X_data = train_data.drop(['label'],axis=1)
train_Y_data = train_data['label']
test_X_data = test_data.drop(['label'],axis=1)
vali_data = test_data['label']
# Out:
# d:\Users\tkhoon\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# d:\Users\tkhoon\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys

# %%
# prefix_title_ctr = train['prefix_title_ctr']
# test_prefix_title_ctr = test['prefix_title_ctr']
# train.drop(['prefix_title_ctr'],axis=1,inplace=True)
# test.drop(['prefix_title_ctr'],axis=1,inplace=True)
# train.drop(['pre_titile_tag_ctr'],axis=1,inplace=True)
# test.drop(['pre_titile_tag_ctr'],axis=1,inplace=True)

# %%
#用xgb跑一下
from pylab import mpl
from matplotlib import pyplot as plt
mpl.rcParams['font.sans-serif'] = ['SimHei'] 
def plot_feature_importance(df,title):
        """
    Plot importances returned by a model. This can work with any measure of
    feature importance provided that higher importance is better. 
    
    Args:
        df (dataframe): feature importances. Must have the features in a column
        called `features` and the importances in a column called `importance
        
    Returns:
        shows a plot of the 15 most importance features
        
        df (dataframe): feature importances sorted by importance (highest to lowest) 
        with a column for normalized importance
        """
        df = df.sort_values('importance',ascending = False,).reset_index()
        df['importance_normalized'] = df['importance']/df['importance'].sum()
        
        plt.figure(figsize=(10,6))
        ax = plt.subplot()
        
        #取前15个feature
        ax.barh(list(reversed(list(df.index[:]))), df['importance_normalized'], align = 'center', edgecolor = 'k')
        
        ax.set_yticks(list(reversed(list(df.index[:]))))
        ax.set_yticklabels(df['feature'])
        
        plt.xlabel('Normalized Importance')
        plt.title(title)
        
        plt.show()
        
        return df
import xgboost as xgb
xgb =  xgb.XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
       colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_delta_step=0,
       max_depth=9, min_child_weight=5, missing=None, n_estimators=10,
       n_jobs=1, nthread=4, objective='binary:logistic', random_state=0,
       reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=27, silent=0,
       subsample=0.8)
model = xgb.fit(train_X_data,train_Y_data,eval_metric='auc')
feature_importance_values = model.feature_importances_
features = list(train_X_data.columns)

xgb_feature_importances = pd.DataFrame({'feature':features,'importance':feature_importance_values})

plot_feature_importance(xgb_feature_importances,'xgb_feature_importances')
from sklearn.metrics import classification_report
xgb_predict_label = model.predict(test_X_data)
print('xgb_predict') 
print(classification_report(vali_data,xgb_predict_label,digits=8))
# Out:
# xgb_predict
#              precision    recall  f1-score   support
#
#           0  0.79812624 0.88677023 0.84011641     31414
#           1  0.76437467 0.62087705 0.68519343     18585
#
# avg / total  0.78558053 0.78793576 0.78253039     49999
# d:\Users\tkhoon\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %%
# train['label'] = train['lable']
# test['label'] = train['lable']

# train.drop('lable',axis=1,inplace=True)
# test.drop('lable',axis=1,inplace=True)


# train['label'] = train['label'].astype(int)
# test['label'] = train['label'].astype(int)
# train_X_data = train.drop('label',axis=1)
# train_Y_data = train['label']
# vali_data = test['label']
# test_X_data = test.drop('label',axis=1)
# pd.set_option('display.max_columns',55)
from sklearn.metrics import classification_report
xgb_predict_label = model.predict(test_X_data)
print('xgb_predict') 
print(classification_report(vali_data,xgb_predict_label,digits=8))
# Out:
# xgb_predict
#              precision    recall  f1-score   support
#
#           0  0.79468756 0.89428280 0.84154872     31414
#           1  0.77327963 0.60947000 0.68167183     18585
#
# avg / total  0.78673007 0.78841577 0.78212129     49999
# d:\Users\tkhoon\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %%
train_pre_title_ctr_rank = pd.read_csv('E:/competionfile/oppo/data/singleFeature/pre_title_ctr_rank.csv',header=None)
test_pre_title_ctr_rank = pd.read_csv('E:/competionfile/oppo/data/singleFeature/test_pre_titletag_ctr_rank.csv',header=None)
train_X_data['pre_title_ctr_rank'] = train_pre_title_ctr_rank
test_X_data['pre_title_ctr_rank'] = test_pre_title_ctr_rank

# %%
# testtrain_X_data
test_X_data
# Out:
#        prefix_count  title_count  tag_count  prefix_tag_count  \
# 0                 4          143       8087                 1
# 1                 2           24       8087                 1
# 2                23           35        373                 6
# 3                84           52      18061                29
# 4                 1            1      18061                 1
# 5                 7            4      18061                 5
# 6                 1            1       3087                 1
# 7               409          706       8087               142
# 8                 2            2        616                 2
# 9                74           75       4163                35
# 10                1            1        472                 1
# 11                8            9        373                 1
# 12                1            1        616                 1
# 13                1            1      18061                 1
# ...
