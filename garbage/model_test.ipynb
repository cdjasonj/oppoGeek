# %%
import pandas as pd
train_data = pd.read_csv('E:/competionfile/oppo/train_data_10_4_2.csv')
test_data = pd.read_csv('E:/competionfile/oppo/test_data_10_4_2.csv')

# %%
train_data
# Out:
#          Unnamed: 0  prefix_pred_0  prefix_pred_1  title_pred_0  title_pred_1  \
# 0                 0       0.624000       0.376000      0.641026  3.589744e-01
# 1                 1       0.627901       0.372099      0.627901  3.720987e-01
# 2                 2       0.627901       0.372099      0.627901  3.720987e-01
# 3                 3       0.647059       0.352941      0.386503  6.134969e-01
# 4                 4       0.627451       0.372549      0.484375  5.156250e-01
# 5                 5       0.627901       0.372099      0.155080  8.449198e-01
# 6                 6       0.696970       0.303030      0.719814  2.801858e-01
# 7                 7       0.642746       0.357254      0.731481  2.685185e-01
# 8                 8       0.627901       0.372099      0.894219  1.057811e-01
# 9                 9       0.671642       0.328358      0.739130  2.608696e-01
# 10               10       0.722222       0.277778      0.993307  6.692645e-03
# ...

# %%
cdata = pd.read_table('E:/competionfile/oppo/new/oppo_round1_train_20180929/oppo_round1_vali_20180929.txt',names=[0,1,2,3,4],header=None,encoding='utf8').astype(str)
cdata.drop( cdata[cdata[3] =='推广'].index , inplace=True )

# %%
data.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-213-047ed65ff157> in <module>()
# ----> 1 data.shape
#
# NameError: name 'data' is not defined

# %%
cdata.shape
# Out:
# (49999, 5)

# %%
train_X_data['lable'] = train_Y_data

test_X_data['lable'] = vali_data
train_X_data.to_csv('E:/competionfile/oppo/traindata/train_data',index=False)
test_X_data.to_csv('E:/competionfile/oppo/traindata/test_data',index=False)

# %%
train_X_data['totalsim'] = train_X_data['query_title_sm']+train_X_data[0]
train_X_data['totalsim2'] = train_X_data[0]*train_X_data['prefix_len']
train_X_data['prefix_tag_ctr2'] = train_X_data['prefix_tag_ctr']*train_X_data['prefix_len']
test_X_data['totalsim'] = test_X_data['query_title_sm']*test_X_data[0]
test_X_data['totalsim2'] = test_X_data[0]*test_X_data['prefix_len']
test_X_data['prefix_tag_ctr2'] = test_X_data['prefix_tag_ctr']*test_X_data['prefix_len']

# %%
train_data_ocr = pd.read_csv('e:/ocrcount.csv',header=None)
test_data_ocr = pd.read_csv('e:/cocrcount.csv',header=None)
train_X_data['ocrcount'] =  train_data_ocr[0]
test_X_data['ocrcount'] =  test_data_ocr[0]

# %%
train_X_data = train_data.drop('label',axis=1)
train_Y_data = train_data['label']

vali_data = test_data['label']
test_X_data = test_data.drop('label',axis=1)

# %%
train_new_f = pd.read_csv('e:/oppo.csv',header = None)
test_new_f = pd.read_csv('e:/oppovalid.csv',header = None)

# %%
train_X_data = pd.concat([train_X_data,train_new_f],axis=1)
test_X_data = pd.concat([test_X_data,test_new_f],axis=1)

# %%
# train_X_data['totalsim']
##拼接起来
train_data_count = pd.read_csv('e:/count.csv',header=None)
test_data_count = pd.read_csv('e:/testcount.csv',header=None)

# %%
# train_X_data['totalsim']
##拼接起来
train_data_ykk = pd.read_csv('e:/ykks.csv',header=None)
test_data_ykk = pd.read_csv('e:/ykks2.csv',header=None)
train_X_data['ykk'] =  train_data_ykk[0]
test_X_data['ykk'] =  test_data_ykk[0]

# %%
# train_X_data['totalsim']
##拼接起来
querytitletagctr = pd.read_csv('e:/querytitletagctr.csv',header=None)
cquerytitletagctr = pd.read_csv('e:/cquerytitletagctr.csv',header=None)
train_X_data['querytitletagctr'] =  querytitletagctr[0]
test_X_data['querytitletagctr'] =  cquerytitletagctr[0]

# %%
train_data_kk = pd.read_csv('e:/kks.csv',header=None)
test_data_kk = pd.read_csv('e:/kks2.csv',header=None)
train_X_data['kk'] =  train_data_kk[0]
test_X_data['kk'] =  test_data_kk[0]

# %%
# train_X_data['totalsim']
##拼接起来
train_data_ctr = pd.read_csv('e:/predctr.csv',header=None)
test_data_ctr = pd.read_csv('e:/testpredctr.csv',header=None)

# %%
# train_X_data.drop([0,'totalsim','totalsim2'],axis=1,inplace=True)
# test_X_data.drop([0,'totalsim','totalsim2'],axis=1,inplace=True)
# train_X_data.drop(['Unnamed: 0'],axis=1,inplace=True)
# test_X_data.drop(['Unnamed: 0'],axis=1,inplace=True)
# train_X_data.drop(['prefix_ctr'],axis=1,inplace=True)
# test_X_data.drop(['prefix_ctr'],axis=1,inplace=True)
# train_X_data.drop(['tag_ctr'],axis=1,inplace=True)
# test_X_data.drop(['tag_ctr'],axis=1,inplace=True)
# train_X_data.drop(['title_pred_0'],axis=1,inplace=True)
# test_X_data.drop(['title_pred_0'],axis=1,inplace=True)
# train_X_data.drop(['title_pred_1'],axis=1,inplace=True)
# test_X_data.drop(['title_pred_1'],axis=1,inplace=True)
# test_X_data.drop( 'prefix_tag_ctr', axis=1,inplace=True)
# train_X_data.drop( 'prefix_tag_ctr', axis=1,inplace=True)
# title_ctr
# train_X_data.drop( 'title_ctr', axis=1,inplace=True)
# test_X_data.drop( 'title_ctr', axis=1,inplace=True)
# train_X_data.drop( 'predictwzdis', axis=1,inplace=True)
# test_X_data.drop( 'predictwzdis', axis=1,inplace=True)
# train_X_data.drop( 'predictwzdisreal', axis=1,inplace=True)
# test_X_data.drop( 'predictwzdisreal', axis=1,inplace=True)
# ttlen = train_X_data['prefix_len']
# cttlen = test_X_data['prefix_len']
train_X_data.drop( 'smi_pre_ti', axis=1,inplace=True)
test_X_data.drop( 'smi_pre_ti', axis=1,inplace=True)
train_X_data.drop( 'query_title_sm', axis=1,inplace=True)
test_X_data.drop( 'query_title_sm', axis=1,inplace=True)
# set( train_X_data.columns ) - set(  test_X_data.columns) 
# clist = [  '健康',               '商品',
#                      '应用',               '影视',              '快应用',
#                      '旅游',               '景点',               '歌手',
#                      '汽车',               '游戏',               '火车','百科',               '知道',               '经验','网站',               '网页',               '航班', '菜谱',               '酒店',               '阅读', '音乐' ]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-202-b36cf2ea9f49> in <module>()
#      22 # ttlen = train_X_data['prefix_len']
#      23 # cttlen = test_X_data['prefix_len']
# ---> 24 train_X_data.drop( 'smi_pre_ti', axis=1,inplace=True)
#      25 test_X_data.drop( 'smi_pre_ti', axis=1,inplace=True)
#      26 train_X_data.drop( 'query_title_sm', axis=1,inplace=True)
#
# d:\Users\tkhoon\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3692                                            index=index, columns=columns,
#    3693                                            level=level, inplace=inplace,
# -> 3694                                            errors=errors)
#    3695
#    3696     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ...

# %%
train_X_data.drop(clist,axis=1,inplace=True)
test_X_data.drop(clist,axis=1,inplace=True)

# %%
# train_X_data['count'] = train_data_count[0]
# test_X_data['count'] = test_data_count[0]
train_X_data['gjctr'] = train_data_ctr[0]
test_X_data['gjctr'] = test_data_ctr[0]

# %%
##加入csim这类
import pandas as pd
train_data_sim = pd.read_csv('e:/sim1.csv',header=None)
test_data_sim = pd.read_csv('e:/csim1.csv',header=None)
train_data_ykk = pd.read_csv('e:/kks.csv',header=None)
test_data_ykk = pd.read_csv('e:/kks2.csv',header=None)
# train_X_data['simm'] =  train_data_sim[0]
# test_X_data['simm'] =  test_data_sim[0]
# train_data_sim2 = pd.read_csv('e:/sim2.csv',header=None)
# test_data_sim2 = pd.read_csv('e:/csim2.csv',header=None)
# train_X_data['simm'] =  train_data_sim2[0]
# test_X_data['csimm'] =  test_data_sim2[0]

# %%
train_data_ykk
# Out:
#                 0
# 0        0.000000
# 1        0.000000
# 2        0.000000
# 3        0.666667
# 4        0.888889
# 5        0.909091
# 6        0.857143
# 7        0.800000
# 8        0.909091
# 9        0.000000
# 10       0.000000
# 11       0.000000
# 12       0.000000
# 13       0.000000
# 14       0.000000
# 15       0.000000
# 16       0.000000
# 17       0.000000
# 18       0.800000
# 19       0.000000
# 20       0.000000
# 21       0.000000
# 22       0.857143
# 23       0.857143
# 24       0.000000
# 25       0.000000
# 26       0.800000
# 27       0.000000
# 28       0.666667
# 29       0.666667
# ...           ...
# 1999968  0.666667
# 1999969  0.857143
# 1999970  0.000000
# 1999971  0.666667
# 1999972  0.666667
# 1999973  0.000000
# 1999974  0.444444
# 1999975  0.833333
# 1999976  0.000000
# 1999977  0.000000
# 1999978  0.000000
# 1999979  0.800000
# 1999980  0.000000
# 1999981  0.000000
# 1999982  0.000000
# 1999983  0.666667
# 1999984  0.000000
# 1999985  0.800000
# ...

# %%
# train_data_pred

# %%
##加入csim这类
train_data_pred = pd.read_csv('e:/predictwzdis.csv',header=None)
test_data_pred = pd.read_csv('e:/cpredictwzdis.csv',header=None)
train_X_data['predictwzdis'] =  train_data_pred[0]
test_X_data['predictwzdis'] =  test_data_pred[0]
# train_data_num = pd.read_csv('e:/containsnum.csv',header=None)
# test_data_num = pd.read_csv('e:/ccontainsnum.csv',header=None)
# train_X_data['containsnum'] =  train_data_num[0]
# test_X_data['containsnum'] =  test_data_num[0]

# %%
train_X_data.shape
# Out:
# (1999994, 10)

# %%
# train_X_data.drop('predictwzdis',axis=1,inplace=True)
# test_X_data.drop('cpredictwzdis',axis=1,inplace=True)
train_X_data['predictwzdisreal'] =  train_X_data['predictwzdis']*train_X_data['containsnum']
test_X_data['predictwzdisreal'] =  test_X_data['predictwzdis']*test_X_data['containsnum']

# %%
train_X_data.columns
# Out:
# Index(['title_tag_ctr', 'prefix_tag_ctr2', 'ocrcount', 'ykk',
#        'querytitletagctr', 'kk', 'count', 'containsnum', 'gjctr',
#        'predictwzdis'],
#       dtype='object')

# %%
test_X_data.columns
# Out:
# Index(['title_tag_ctr', 'prefix_tag_ctr2', 'ocrcount', 'ykk',
#        'querytitletagctr', 'kk', 'count', 'containsnum', 'gjctr',
#        'predictwzdis'],
#       dtype='object')

# %%
set(test_X_data.columns)  - set(train_X_data.columns)
# Out:
# set()

# %%
#用xgb跑一下
from pylab import mpl
from matplotlib import pyplot as plt
mpl.rcParams['font.sans-serif'] = ['SimHei'] 
def plot_feature_importance(df,title):
        """
    Plot importances returned by a model. This can work with any measure of
    feature importance provided that higher importance is better. 
    
    Args:
        df (dataframe): feature importances. Must have the features in a column
        called `features` and the importances in a column called `importance
        
    Returns:
        shows a plot of the 15 most importance features
        
        df (dataframe): feature importances sorted by importance (highest to lowest) 
        with a column for normalized importance
        """
        df = df.sort_values('importance',ascending = False,).reset_index()
        df['importance_normalized'] = df['importance']/df['importance'].sum()
        
        plt.figure(figsize=(10,6))
        ax = plt.subplot()
        
        #取前15个feature
        ax.barh(list(reversed(list(df.index[:]))), df['importance_normalized'], align = 'center', edgecolor = 'k')
        
        ax.set_yticks(list(reversed(list(df.index[:]))))
        ax.set_yticklabels(df['feature'])
        
        plt.xlabel('Normalized Importance')
        plt.title(title)
        
        plt.show()
        
        return df
def myFeval(   preds, train):
#     aa = pd.Series(train.get_label()).map( lambda x: 1 if x >= 0.5 else 0 )
#     print()
    score = f1_score(train.get_label(),pd.Series(preds).map( lambda x: 1 if x >= 0.5 else 0 ))
    return 'myFeval',score,False
import xgboost as xgb
xgb = xgb.XGBClassifier(max_depth=10,
                        silent=0,
                        learning_rate=0.1, 
                        n_estimators=100, 
                        nthread=-1, 
                        gamma=0,
                        min_child_weight=1, 
                        max_delta_step=0, 
                        subsample=0.85, 
                        colsample_bytree=0.7, 
                        colsample_bylevel=1, 
                        reg_alpha=0, 
                        reg_lambda=1, 
                        scale_pos_weight=1, 
                        seed=1440, 
                        missing=None)

model = xgb.fit(train_X_data,train_Y_data,eval_metric='auc')
feature_importance_values = model.feature_importances_
features = list(train_X_data.columns)

xgb_feature_importances = pd.DataFrame({'feature':features,'importance':feature_importance_values})

plot_feature_importance(xgb_feature_importances,'xgb_feature_importances')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-32e79ece662c> in <module>()
#      59 #                         missing=None)
#      60
# ---> 61 model = xgb.fit(train_X_data,train_Y_data,eval_metric='auc')
#      62 feature_importance_values = model.feature_importances_
#      63 features = list(train_X_data.columns)
#
# AttributeError: module 'xgboost' has no attribute 'fit'

# %%
from sklearn.metrics import f1_score
import lightgbm as lgb
params = {'metric': 'l1',
          'boosting_type': 'gbdt',
          'max_depth':10,
          'num_leaves':300,
          'num_threads':4,
          'objective':'binary',
          'bagging_fraction':0.7,
          # 'bagging_freq':1,
          'learning_rate' : 0.022,
#           'min_data_in_leaf' : 500,
#           'min_data_per_group' : 1,
          # 'weight' : ''
          }

def myFeval(   preds, train):
#     aa = pd.Series(train.get_label()).map( lambda x: 1 if x >= 0.5 else 0 )
#     print()
    score = f1_score(train.get_label(),pd.Series(preds).map( lambda x: 1 if x >= 0.5 else 0 ))
    return 'myFeval',score,False
train_data = lgb.Dataset( train_X_data , train_Y_data  ,free_raw_data=False ,  )
test_data = lgb.Dataset( test_X_data , vali_data , reference= train_data )
gbm = lgb.train(params,train_data,valid_sets=test_data,num_boost_round=3,feval = myFeval )
# Out:
# [1]	valid_0's l1: 0.384891	valid_0's myFeval: 0.70433
# [2]	valid_0's l1: 0.397478	valid_0's myFeval: 0.712808
# [3]	valid_0's l1: 0.409884	valid_0's myFeval: 0.728235

# %%
train_X_data.columns
# Out:
# Index(['title_tag_ctr', 'prefix_tag_ctr2', 'ocrcount', 'ykk',
#        'querytitletagctr', 'kk', 'count', 'containsnum', 'gjctr',
#        'predictwzdis'],
#       dtype='object')

# %%
print('Feature importances:', list(gbm.feature_importance()))
# Out:
# Feature importances: [4358, 2512, 2566, 6977, 525, 61, 725, 183, 4273, 10, 2999, 525]

# %%
from sklearn.metrics import classification_report
xgb_predict_label = gbm.predict(test_X_data)
xgb_predict_label = pd.Series(xgb_predict_label).map( lambda x : 1 if x >= 0.5 else 0 )
print('lgb_predict')
print(classification_report(vali_data,xgb_predict_label,digits = 4))
# Out:
# lgb_predict
#              precision    recall  f1-score   support
#
#           0     0.8304    0.8681    0.8489     31414
#           1     0.7586    0.7003    0.7283     18585
#
# avg / total     0.8037    0.8058    0.8040     49999

# %%
test_X_data[9:10]
# Out:
#    title_tag_ctr  smi_pre_ti  query_title_sm  prefix_tag_ctr2  ocrcount  ykk  \
# 9       0.151884    0.333333            0.75         0.142967      3796    1
#
#    querytitletagctr        kk  count  containsnum     gjctr  predictwzdis
# 9           0.14521  0.666667   3796            1  0.006059      0.053188

# %%
pd.set_option('max_columns',50)

# %%
cdata.iloc[cdata[ cdata[2] == '支付宝' ][ cdata[3] == '应用' ].index ][0:1]
# Out:
# d:\Users\tkhoon\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#      0                                                  1    2   3  4
# 721  支  {"支付宝下载": "0.012", "支气管炎": "0.010", "支付宝提现要手续费...  支付宝  应用  1

# %%
test_X_data.iloc[cdata[ cdata[2] == '支付宝' ][ cdata[3] == '应用' ].index ][0:1]
# Out:
# d:\Users\tkhoon\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#      prefix_len  title_tag_ctr  smi_pre_ti  query_title_sm  prefix_tag_ctr2  \
# 721           1       0.958219         0.5             1.0         0.955963
#
#      ocrcount  ykk  querytitletagctr        kk  count     gjctr  predictwzdis  \
# 721      3796    1          0.956718  0.666667   3796  0.017054      0.141126
#
#      containsnum  predictwzdisreal
# 721            1          0.141126

# %%
##训练结果中支付宝应用被点击的平均概率
float(xgb_predict_label[cdata[ cdata[2] == '支付宝' ][ cdata[3] == '应用' ].index].astype(int).mean())
# Out:
# d:\Users\tkhoon\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# 0.4

# %%
xgb_predict_label[cdata[ cdata[2] == '支付宝' ][ cdata[3] == '应用' ].index].astype(int)##测试集中支付宝应用被点击的平均概率
cdata[ cdata[2] == '支付宝' ][ cdata[3] == '应用' ][4].astype(int).mean()
# Out:
# d:\Users\tkhoon\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# 0.88

# %%
boolset = [False]*len(xgb_predict_label)
for i in range(0 , len( xgb_predict_label )):
    if vali_data[i] == 1 and xgb_predict_label[i] == 0:
        boolset[i]=True
cdata[ boolset ]
# Out:
#                 0                                                  1  \
# 9               支  {"支付宝下载": "0.012", "支气管炎": "0.010", "支付宝提现要手续费...
# 12         东风风行x3     {"东风风行x3报价及图片": "0.119", "东风风行x3多少钱": "0.073"}
# 22             压面  {"压面条机": "0.053", "压面机": "0.339", "压面机价格及图片": ...
# 30             地图  {"地图查询": "0.005", "地图百度": "0.005", "地图导航": "0....
# 46             车生  {"车生活app下载": "0.048", "车生锈在喷漆有影响吗": "0.044", "...
# 50             排骨  {"排骨怎么做好吃": "0.025", "排骨汤的做法": "0.063", "排骨炖玉米...
# 56             酸汤  {"酸汤鱼的做法": "0.047", "酸汤面": "0.077", "酸汤面的家常做法"...
# 64           复方苯佐                              {"复方苯佐卡因凝胶": "1.000"}
# 67              星  {"星空图片": "0.010", "星辰影院": "0.010", "星辰变": "0.0...
# 77           玖富万卡  {"玖富万卡怎么样": "0.014", "玖富万卡上征信吗": "0.121", "玖富万...
# 84            小米8  {"小米8探索版": "0.089", "小米8se怎么样": "0.005", "小米8最...
# 92            肚子疼  {"肚子疼图片": "0.021", "肚子疼痛的原因": "0.049", "肚子疼视频"...
# 102           马桶盖  {"马桶盖价格": "0.033", "马桶盖怎么安装": "0.057", "马桶盖子怎么...
# ...

# %%
from sklearn.metrics import classification_report
xgb_predict_label = model.predict(test_X_data)
print('xgb_predict')
print(classification_report(vali_data,xgb_predict_label))
# Out:
# xgb_predict
#              precision    recall  f1-score   support
#
#           0       0.81      0.89      0.85     31414
#           1       0.77      0.65      0.70     18585
#
# avg / total       0.79      0.80      0.79     49999
# C:\Users\thinkpad\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %%
#输出预测结果
import numpy as np 
np.savetxt('xgb_predict_label.txt',xgb_predict_label)

# %%
from pylab import mpl
from matplotlib import pyplot as plt
mpl.rcParams['font.sans-serif'] = ['SimHei'] 
def plot_feature_importance(df,title):
        """
    Plot importances returned by a model. This can work with any measure of
    feature importance provided that higher importance is better. 
    
    Args:
        df (dataframe): feature importances. Must have the features in a column
        called `features` and the importances in a column called `importance
        
    Returns:
        shows a plot of the 15 most importance features
        
        df (dataframe): feature importances sorted by importance (highest to lowest) 
        with a column for normalized importance
        """
        df = df.sort_values('importance',ascending = False,).reset_index()
        df['importance_normalized'] = df['importance']/df['importance'].sum()
        
        plt.figure(figsize=(10,6))
        ax = plt.subplot()
        
        #取前15个feature
        ax.barh(list(reversed(list(df.index[:]))), df['importance_normalized'], align = 'center', edgecolor = 'k')
        
        ax.set_yticks(list(reversed(list(df.index[:]))))
        ax.set_yticklabels(df['feature'])
        
        plt.xlabel('Normalized Importance')
        plt.title(title)
        
        plt.show()
        
        return df

# %%
train_X_data[0] = train_X_data[0].fillna(0)
test_X_data[0] = test_X_data[0].fillna(0)
# Out:
#          prefix_pred_0  prefix_pred_1  title_pred_0  title_pred_1  健康  商品  应用  \
# 0             0.624000       0.376000      0.641026  3.589744e-01   0   0   0
# 1             0.627901       0.372099      0.627901  3.720987e-01   1   0   0
# 2             0.627901       0.372099      0.627901  3.720987e-01   0   0   0
# 3             0.647059       0.352941      0.386503  6.134969e-01   0   0   0
# 4             0.627451       0.372549      0.484375  5.156250e-01   0   0   0
# 5             0.627901       0.372099      0.155080  8.449198e-01   0   0   0
# 6             0.696970       0.303030      0.719814  2.801858e-01   0   0   1
# 7             0.642746       0.357254      0.731481  2.685185e-01   0   0   0
# 8             0.627901       0.372099      0.894219  1.057811e-01   0   0   0
# 9             0.671642       0.328358      0.739130  2.608696e-01   0   0   0
# 10            0.722222       0.277778      0.993307  6.692645e-03   0   0   0
# ...

# %%
from sklearn.linear_model import LinearRegression
LR = LinearRegression()
model = LR.fit(train_X_data,train_Y_data)

lr_predict_label = model.predict(test_X_data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-129-69f78ea270ef> in <module>()
#       1 from sklearn.linear_model import LinearRegression
#       2 LR = LinearRegression()
# ----> 3 model = LR.fit(train_X_data,train_Y_data)
#       4
#       5 lr_predict_label = model.predict(test_X_data)
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\base.py in fit(self, X, y, sample_weight)
#     480         n_jobs_ = self.n_jobs
#     481         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 482                          y_numeric=True, multi_output=True)
#     483
#     484         if sample_weight is not None and np.atleast_1d(sample_weight).ndim > 1:
#
# ...

# %%
lr_predict_label = pd.DataFrame(lr_predict_label)
lr_predict_label
# Out:
#               0
# 0      0.027832
# 1      0.043762
# 2      0.043884
# 3      0.067749
# 4      0.012207
# 5      0.195374
# 6      0.617188
# 7      0.101379
# 8      0.587097
# 9      0.137878
# 10    -0.111450
# 11     0.033997
# 12     0.492188
# 13    -0.008484
# 14     0.009399
# 15     0.944458
# 16     0.948792
# 17     0.361572
# 18     0.779297
# 19     0.041809
# 20     0.153564
# 21     0.012146
# 22     0.022583
# 23     0.025696
# 24     0.101379
# 25     0.737671
# 26     0.037170
# 27     0.833557
# 28     0.027466
# 29     0.062195
# ...         ...
# 49969  0.094360
# 49970  0.393311
# 49971  0.393982
# 49972  0.272095
# 49973  0.491272
# 49974  0.306213
# 49975  0.304932
# 49976  0.398315
# 49977  0.398315
# 49978  0.389465
# 49979  0.403564
# 49980  0.398987
# 49981  0.273193
# 49982  0.403748
# 49983  0.405212
# 49984  0.354309
# 49985  0.396179
# 49986  0.340576
# 49987  0.336243
# 49988  0.253662
# 49989  0.381470
# 49990  0.398987
# 49991  0.389709
# ...

# %%
from sklearn.metrics import classification_report
print('lr_predict')
print(classification_report(vali_data,lr_predict_label[0].map(lambda x:1 if x >= 0.5 else 0)))
# Out:
# lr_predict
#              precision    recall  f1-score   support
#
#           0       0.79      0.91      0.84     31414
#           1       0.79      0.59      0.68     18585
#
# avg / total       0.79      0.79      0.78     49999

# %%
##重新来计算语义相似度
